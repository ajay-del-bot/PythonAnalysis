# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay-del-bot/PythonAnalysis/blob/main/CancerDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\Ajay's PC\\breastCancer.csv")

# %%
df.head()
# Out:
#         id  clump_thickness  size_uniformity  shape_uniformity  \
# 0  1000025                5                1                 1
# 1  1002945                5                4                 4
# 2  1015425                3                1                 1
# 3  1016277                6                8                 8
# 4  1017023                4                1                 1
#
#    marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                  1                2             1                3
# 1                  5                7            10                3
# 2                  1                2             2                3
# 3                  1                3             4                3
# 4                  3                2             1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# 2                1        1      2
# ...

# %%
df.shape
# Out:
# (699, 11)

# %% [markdown]
# # Data PreProcessing

# %%
df['class'].value_counts()
# Out:
# 2    458
# 4    241
# Name: class, dtype: int64

# %% [markdown]
# 2 is for Benign<BR>
# 4 is for Malignant

# %%
df.dtypes
# Out:
# id                    int64
# clump_thickness       int64
# size_uniformity       int64
# shape_uniformity      int64
# marginal_adhesion     int64
# epithelial_size       int64
# bare_nucleoli        object
# bland_chromatin       int64
# normal_nucleoli       int64
# mitoses               int64
# class                 int64
# dtype: object

# %%
df['bare_nucleoli'].value_counts()
# Out:
# 1     402
# 10    132
# 5      30
# 2      30
# 3      28
# 8      21
# 4      19
# ?      16
# 9       9
# 7       8
# 6       4
# Name: bare_nucleoli, dtype: int64

# %%
df[df['bare_nucleoli']=='?']
# Out:
#           id  clump_thickness  size_uniformity  shape_uniformity  \
# 23   1057013                8                4                 5
# 40   1096800                6                6                 6
# 139  1183246                1                1                 1
# 145  1184840                1                1                 3
# 158  1193683                1                1                 2
# 164  1197510                5                1                 1
# 235  1241232                3                1                 4
# 249   169356                3                1                 1
# 275   432809                3                1                 3
# 292   563649                8                8                 8
# 294   606140                1                1                 1
# 297    61634                5                4                 3
# 315   704168                4                6                 5
# ...

# %%
digits_in_bare_nucleoli = pd.DataFrame(df.bare_nucleoli.str.isdigit())
digits_in_bare_nucleoli
# Out:
#      bare_nucleoli
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# ..             ...
# 694           True
# 695           True
# 696           True
# 697           True
# 698           True
#
# [699 rows x 1 columns]

# %%
df = df.replace('?', np.nan)

# %%
df.median()
# Out:
# id                   1171710.0
# clump_thickness            4.0
# size_uniformity            1.0
# shape_uniformity           1.0
# marginal_adhesion          1.0
# epithelial_size            2.0
# bare_nucleoli              1.0
# bland_chromatin            3.0
# normal_nucleoli            1.0
# mitoses                    1.0
# class                      2.0
# dtype: float64

# %%
df = df.fillna(df.median())

# %%
df['bare_nucleoli'].value_counts()
# Out:
# 1      402
# 10     132
# 5       30
# 2       30
# 3       28
# 8       21
# 4       19
# 1.0     16
# 9        9
# 7        8
# 6        4
# Name: bare_nucleoli, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.tail()
# Out:
#          id  clump_thickness  size_uniformity  shape_uniformity  \
# 694  776715                3                1                 1
# 695  841769                2                1                 1
# 696  888820                5               10                10
# 697  897471                4                8                 6
# 698  897471                4                8                 8
#
#      marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 694                  1                3             2                1
# 695                  1                2             1                1
# 696                  3                7             3                8
# 697                  4                3             4               10
# 698                  5                4             5               10
#
#      normal_nucleoli  mitoses  class
# 694                1        1      2
# 695                1        1      2
# 696               10        2      4
# ...

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.describe().T
# Out:
#                    count      mean       std  min  25%  50%  75%   max
# clump_thickness    699.0  4.417740  2.815741  1.0  2.0  4.0  6.0  10.0
# size_uniformity    699.0  3.134478  3.051459  1.0  1.0  1.0  5.0  10.0
# shape_uniformity   699.0  3.207439  2.971913  1.0  1.0  1.0  5.0  10.0
# marginal_adhesion  699.0  2.806867  2.855379  1.0  1.0  1.0  4.0  10.0
# epithelial_size    699.0  3.216023  2.214300  1.0  2.0  2.0  4.0  10.0
# bland_chromatin    699.0  3.437768  2.438364  1.0  2.0  3.0  5.0  10.0
# normal_nucleoli    699.0  2.866953  3.053634  1.0  1.0  1.0  4.0  10.0
# mitoses            699.0  1.589413  1.715078  1.0  1.0  1.0  1.0  10.0
# class              699.0  2.689557  0.951273  2.0  2.0  2.0  4.0   4.0

# %% [markdown]
# ### Univariate Data Analysis

# %%
sns.displot(df['class'])

# %% [markdown]
# ### Multivariate Data Analysis

# %%
df.hist(bins=20, figsize=(30,30), layout=(6,3));

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(data=df, orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can spot the outiers

# %%
df.corr()
# Out:
#                    clump_thickness  size_uniformity  shape_uniformity  \
# clump_thickness           1.000000         0.644913          0.654589
# size_uniformity           0.644913         1.000000          0.906882
# shape_uniformity          0.654589         0.906882          1.000000
# marginal_adhesion         0.486356         0.705582          0.683079
# epithelial_size           0.521816         0.751799          0.719668
# bland_chromatin           0.558428         0.755721          0.735948
# normal_nucleoli           0.535835         0.722865          0.719446
# mitoses                   0.350034         0.458693          0.438911
# class                     0.716001         0.817904          0.818934
#
#                    marginal_adhesion  epithelial_size  bland_chromatin  \
# clump_thickness             0.486356         0.521816         0.558428
# size_uniformity             0.705582         0.751799         0.755721
# ...

# %%
plt.figure(figsize=(35, 15))
sns.heatmap(df.corr(), vmax=1, square=True, annot=True, cmap='viridis')
plt.title('Correlation between features')
plt.show()

# %%
sns.pairplot(df, diag_kind='kde')

# %% [markdown]
# # Building Our Model

# %%
df.head()
# Out:
#    clump_thickness  size_uniformity  shape_uniformity  marginal_adhesion  \
# 0                5                1                 1                  1
# 1                5                4                 4                  5
# 2                3                1                 1                  1
# 3                6                8                 8                  1
# 4                4                1                 1                  3
#
#    epithelial_size bare_nucleoli  bland_chromatin  normal_nucleoli  mitoses  \
# 0                2             1                3                1        1
# 1                7            10                3                2        1
# 2                2             2                3                1        1
# 3                3             4                3                7        1
# 4                2             1                3                1        1
#
#    class
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %%
X = df.drop('class', axis=1)
Y = df['class']

# %%
from sklearn.model_selection import train_test_split
#Split 70:30
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %% [markdown]
# ## KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors=5, weights='distance')

# %%
KNN.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
KNN_predicted = KNN.predict(X_test)
KNN_predicted
# Out:
# array([2, 2, 2, 4, 2, 2, 4, 2, 2, 2, 4, 4, 2, 2, 4, 4, 2, 2, 2, 2, 2, 4,
#        4, 2, 4, 2, 4, 4, 2, 2, 2, 4, 4, 4, 4, 4, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 4, 2, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 4, 2,
#        4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 2, 2, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4, 2, 4, 2, 2, 2, 2, 2, 4,
#        2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4,
#        4, 4, 4, 4, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4,
#        4, 2, 2, 2, 2, 2, 4, 4, 4, 2, 2, 2], dtype=int64)

# %%
Y_test.values
# Out:
# array([2, 2, 2, 4, 2, 2, 4, 2, 2, 2, 4, 4, 2, 4, 4, 4, 2, 2, 2, 2, 2, 4,
#        4, 2, 4, 2, 4, 2, 2, 2, 2, 4, 4, 4, 4, 4, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4, 2, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 4, 2, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 4, 2,
#        4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 2, 4, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4, 2, 4, 2, 2, 2, 2, 2, 4,
#        2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 2, 2, 2, 2, 4, 4, 2, 2, 4,
#        4, 4, 4, 4, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4,
#        4, 2, 2, 2, 2, 2, 4, 4, 4, 2, 4, 2], dtype=int64)

# %%
from scipy.stats import zscore
print("KNeighborsClassifier prediction score: {0:.4g}%".format(KNN.score(X_test, Y_test)*100))
# Out:
# KNeighborsClassifier prediction score: 97.14%

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
svc = SVC(gamma=0.025, C=3)
svc.fit(X_train, Y_train)
# Out:
# SVC(C=3, gamma=0.025)

# %%
SVC_Predicted = svc.predict(X_test)
SVC_Predicted
# Out:
# array([2, 2, 2, 4, 2, 2, 4, 2, 2, 2, 4, 4, 2, 2, 4, 4, 2, 2, 2, 2, 2, 4,
#        4, 2, 4, 2, 4, 4, 2, 2, 2, 4, 4, 4, 4, 4, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4, 2, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 4, 2, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 4, 4, 2, 2, 4, 4, 2, 4, 2,
#        4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 2, 4, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4, 2, 4, 2, 2, 2, 2, 2, 4,
#        2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 2, 2, 2, 2, 4, 4, 2, 2, 4,
#        4, 4, 4, 4, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4,
#        4, 2, 2, 2, 2, 2, 4, 4, 4, 2, 2, 2], dtype=int64)

# %%
print("SupportVectorMachine prediction score: {0:.4g}%".format(svc.score(X_test, Y_test)*100))
# Out:
# SupportVectorMachine prediction score: 98.1%

# %%
knnPredicts = pd.DataFrame(KNN_predicted)
svcPredicts  = pd.DataFrame(SVC_Predicted)

# %%
df1 = pd.concat([knnPredicts, svcPredicts], axis=1)
df1.columns = [['KNNPredictions', 'SVCPredictions']]

# %%
df1
# Out:
#     KNNPredictions SVCPredictions
# 0                2              2
# 1                2              2
# 2                2              2
# 3                4              4
# 4                2              2
# ..             ...            ...
# 205              4              4
# 206              4              4
# 207              2              2
# 208              2              2
# 209              2              2
#
# [210 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
print("KNN report:")
print('***'*20)
print(classification_report(Y_test, KNN_predicted))
print('***'*20)
# Out:
# KNN report:
# ************************************************************
#               precision    recall  f1-score   support
#
#            2       0.96      0.99      0.98       137
#            4       0.99      0.93      0.96        73
#
#     accuracy                           0.97       210
#    macro avg       0.98      0.96      0.97       210
# weighted avg       0.97      0.97      0.97       210
#
# ************************************************************

# %%
print("SVC report:")
print('***'*20)
print(classification_report(Y_test, SVC_Predicted))
print('***'*20)
# Out:
# SVC report:
# ************************************************************
#               precision    recall  f1-score   support
#
#            2       0.99      0.99      0.99       137
#            4       0.97      0.97      0.97        73
#
#     accuracy                           0.98       210
#    macro avg       0.98      0.98      0.98       210
# weighted avg       0.98      0.98      0.98       210
#
# ************************************************************

# %%
from sklearn.metrics import confusion_matrix

print("Confusion Matrix for KNN:")
cm = confusion_matrix(Y_test, KNN_predicted, labels=[2,4])
df_cm = pd.DataFrame(cm, index=[i for i in ['Actual B','Actual M']], columns=[i for i in ['Predict B', 'Predict M']])
plt.figure(figsize=(7,5))
sns.heatmap(df_cm, annot=True)
# Out:
# Confusion Matrix for KNN:
# <AxesSubplot:>

# %%
print("Confusion Matrix for SVC:")
cm = confusion_matrix(Y_test, SVC_Predicted, labels=[2,4])
df_cm = pd.DataFrame(cm, index=[i for i in ['Actual B','Actual M']], columns=[i for i in ['Predict B', 'Predict M']])
plt.figure(figsize=(7,5))
sns.heatmap(df_cm, annot=True)
# Out:
# Confusion Matrix for SVC:
# <AxesSubplot:>
